# %%
import csv

        
def calc_difference(first,second):
    difference = 0

    if first == "" and second == "":
        return difference
    elif first == " ":
        first = second
        return difference

    elif second == " ":
        second = first
        return difference
    else:
        
        if(first == "F"):
            first = "E"
        if(second == "F" ):
            second ="E"
        difference = (ord(first) - ord(second))

    return difference


def get_firstID(filepath):
    with open(filepath) as file:
        reader = csv.reader(file)
        reader.__next__()
        num = reader.__next__()[0]
    return num
def calculate_improvement(filepath):

    with open(filepath) as file:
        reader = csv.reader(file)
        reader.__next__() #Skip first row
        points = 0
        IDnum = 0

        IDnum = get_firstID(filepath)

        for row in reader:

            firstNineWeeks = row[5]
            secondNineWeeks = row[6]
            checkID = row[0]

            if (IDnum != checkID):
                print(""+ IDnum + " has " + str(points) + " points")
                points = 0
                IDnum = checkID
            
            points += calc_difference(firstNineWeeks, secondNineWeeks)

            
   

            
            

calculate_improvement('./data/StudentData7160_6012.csv')
calculate_improvement('./data/StudentData7160_7014.csv')
calculate_improvement('./data/StudentData7160_7160.csv')
# Out:
# ['0089326', '6012', '8', 'ADRIANA', 'CABRERA', 'A', 'A', 'M/J Chorus 2']
# First nine weeks:  A
# 0
# ['0089326', '6012', '8', 'ADRIANA', 'CABRERA', 'A', 'B', 'Geometry Honors, Gifted']
# First nine weeks:  A
# -1
# ['0089326', '6012', '8', 'ADRIANA', 'CABRERA', 'C', 'B', 'M/J World History, Advanced, Gifted']
# First nine weeks:  C
# 0
# ['0089326', '6012', '8', 'ADRIANA', 'CABRERA', 'A', 'B', 'Algebra 1 Honors Gifted']
# First nine weeks:  A
# -1
# ['0089326', '6012', '8', 'ADRIANA', 'CABRERA', 'C', 'C', 'Italian 2']
# First nine weeks:  C
# -1
# ['0089326', '6012', '8', 'ADRIANA', 'CABRERA', 'C', 'B', 'Biology 1 Honors, Gifted']
# First nine weeks:  C
# 0
# ['0089326', '6012', '8', 'ADRIANA', 'CABRERA', 'B', 'A', 'M/J Dance 2']
# First nine weeks:  B
# 1
# ['0089326', '6012', '8', 'ADRIANA', 'CABRERA', 'B', 'C', 'M/J Language Arts 3,Advanced/Gifted']
# First nine weeks:  B
# 0
# ['0143026', '6012', '7', 'JAMARIYA', 'MARCH', 'B', 'A', 'M/J Dance 1']
# First nine weeks:  B
# 0089326 has 0 points
# 1
# ['0143026', '6012', '7', 'JAMARIYA', 'MARCH', 'D', 'C', 'M/J Grade 7 Mathematics Advanced']
# First nine weeks:  D
# 2
# ['0143026', '6012', '7', 'JAMARIYA', 'MARCH', 'C', ' ', 'Exploring Technology and Career Planning']
# First nine weeks:  C
# Second nine weeks C
# 2
# ['0143026', '6012', '7', 'JAMARIYA', 'MARCH', 'B', 'B', 'M/J Creative Writing 1']
# First nine weeks:  B
# 2
# ['0143026', '6012', '7', 'JAMARIYA', 'MARCH', 'C', 'C', 'M/J Civics, Advanced']
# First nine weeks:  C
# 2
# ['0143026', '6012', '7', 'JAMARIYA', 'MARCH', ' ', 'B', 'Introduction to Technology']
# First nine weeks:
# 2
# ['0143026', '6012', '7', 'JAMARIYA', 'MARCH', 'C', 'C', 'M/J Language Arts 2, Advanced']
# First nine weeks:  C
# 2
# ['0143026', '6012', '7', 'JAMARIYA', 'MARCH', 'B', 'B', 'M/J Theatre 1']
# First nine weeks:  B
# 2
# ['0143026', '6012', '7', 'JAMARIYA', 'MARCH', 'C', 'B', 'Physical Science Honors']
# First nine weeks:  C
# 3
# ['0209643', '6012', '8', 'LISBETH', 'DIAZ', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0143026 has 3 points
# 0
# ['0209643', '6012', '8', 'LISBETH', 'DIAZ', 'F', 'F', 'M/J World History']
# First nine weeks:  F
# 0
# ['0209643', '6012', '8', 'LISBETH', 'DIAZ', 'A', 'A', 'M/J Chorus 1']
# First nine weeks:  A
# 0
# ['0209643', '6012', '8', 'LISBETH', 'DIAZ', 'F', 'F', 'M/J Intensive Reading (MC) Grade 8']
# First nine weeks:  F
# 0
# ['0209643', '6012', '8', 'LISBETH', 'DIAZ', 'D', 'F', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  D
# -1
# ['0209643', '6012', '8', 'LISBETH', 'DIAZ', 'D', 'C', 'M/J Comprehensive Science 3']
# First nine weeks:  D
# 0
# ['0209643', '6012', '8', 'LISBETH', 'DIAZ', 'F', 'F', 'M/J Language Arts 3']
# First nine weeks:  F
# 0
# ['0209643', '6012', '8', 'LISBETH', 'DIAZ', 'F', 'F', 'M/J Intensive Mathematics (Grade 8)']
# First nine weeks:  F
# 0
# ['0212905', '6012', '8', 'JOSHUA', 'RADCLIFF', ' ', ' ', 'Speech Therapy: 6-8']
# First nine weeks:
# 0209643 has 0 points
# 0
# ['0212905', '6012', '8', 'JOSHUA', 'RADCLIFF', 'C', 'C', 'Algebra 1 Honors']
# First nine weeks:  C
# 0
# ['0212905', '6012', '8', 'JOSHUA', 'RADCLIFF', 'C', 'B', 'Biology 1 Honors']
# First nine weeks:  C
# 1
# ['0212905', '6012', '8', 'JOSHUA', 'RADCLIFF', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 1
# ['0212905', '6012', '8', 'JOSHUA', 'RADCLIFF', 'C', 'C', 'M/J Language Arts 3']
# First nine weeks:  C
# 1
# ['0212905', '6012', '8', 'JOSHUA', 'RADCLIFF', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 1
# ['0212905', '6012', '8', 'JOSHUA', 'RADCLIFF', 'C', 'C', 'M/J World History']
# First nine weeks:  C
# 1
# ['0212905', '6012', '8', 'JOSHUA', 'RADCLIFF', 'B', 'C', 'M/J Research 1']
# First nine weeks:  B
# 0
# ['0212905', '6012', '8', 'JOSHUA', 'RADCLIFF', 'C', 'C', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# 0
# ['0212905', '6012', '8', 'JOSHUA', 'RADCLIFF', 'B', 'B', 'Learning Strategies: 6-8']
# First nine weeks:  B
# 0
# ['0230270', '6012', '8', 'MICHAEL', 'PEREZ', 'C', 'C', 'German 1']
# First nine weeks:  C
# 0212905 has 0 points
# 0
# ['0230270', '6012', '8', 'MICHAEL', 'PEREZ', 'F', 'C', 'M/J World History']
# First nine weeks:  F
# 2
# ['0230270', '6012', '8', 'MICHAEL', 'PEREZ', 'D', 'C', 'Algebra 1 Honors']
# First nine weeks:  D
# 3
# ['0230270', '6012', '8', 'MICHAEL', 'PEREZ', 'D', 'C', 'Physical Science Honors']
# First nine weeks:  D
# 4
# ['0230270', '6012', '8', 'MICHAEL', 'PEREZ', 'F', 'C', 'M/J Language Arts 3']
# First nine weeks:  F
# 6
# ['0230270', '6012', '8', 'MICHAEL', 'PEREZ', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 6
# ['0230270', '6012', '8', 'MICHAEL', 'PEREZ', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 6
# ['0230270', '6012', '8', 'MICHAEL', 'PEREZ', 'D', 'C', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  D
# 7
# ['0230270', '6012', '8', 'MICHAEL', 'PEREZ', 'C', 'C', 'M/J Intensive Reading (MC) Grade 8']
# First nine weeks:  C
# 7
# ['0246656', '6012', '7', 'CHRISTINA', 'MEDEROS', ' ', 'A', 'M/J Team Sports - Grade 7']
# First nine weeks:
# 0230270 has 7 points
# 0
# ['0246656', '6012', '7', 'CHRISTINA', 'MEDEROS', 'B', 'A', 'M/J Civics, Advanced, Gifted']
# First nine weeks:  B
# 1
# ['0246656', '6012', '7', 'CHRISTINA', 'MEDEROS', 'D', 'C', 'M/J Language Arts 2,Advanced/Gifted']
# First nine weeks:  D
# 2
# ['0246656', '6012', '7', 'CHRISTINA', 'MEDEROS', 'A', ' ', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:  A
# Second nine weeks A
# 2
# ['0246656', '6012', '7', 'CHRISTINA', 'MEDEROS', 'B', 'B', 'M/J Creative Writing 1']
# First nine weeks:  B
# 2
# ['0246656', '6012', '7', 'CHRISTINA', 'MEDEROS', 'C', 'C', 'M/J Grade 7 Mathematics Advanced, Gifted']
# First nine weeks:  C
# 2
# ['0246656', '6012', '7', 'CHRISTINA', 'MEDEROS', 'D', 'D', 'Physical Science Honors Gifted']
# First nine weeks:  D
# 2
# ['0246656', '6012', '7', 'CHRISTINA', 'MEDEROS', 'A', 'A', 'M/J Theatre 1']
# First nine weeks:  A
# 2
# ['0246656', '6012', '7', 'CHRISTINA', 'MEDEROS', 'B', 'B', 'Spanish for Spanish Speakers 1']
# First nine weeks:  B
# 2
# ['0248013', '6012', '6', 'ANTHONY', 'CASTILLO', ' ', 'A', 'Business Keyboarding and Career Planning']
# First nine weeks:
# 0246656 has 2 points
# 0
# ['0248013', '6012', '6', 'ANTHONY', 'CASTILLO', 'C', 'B', 'M/J Grade 6 Mathematics Advanced']
# First nine weeks:  C
# 1
# ['0248013', '6012', '6', 'ANTHONY', 'CASTILLO', 'A', ' ', 'M/J Fitness - Grade 6']
# First nine weeks:  A
# Second nine weeks A
# 1
# ['0248013', '6012', '6', 'ANTHONY', 'CASTILLO', ' ', 'A', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:
# 1
# ['0248013', '6012', '6', 'ANTHONY', 'CASTILLO', 'B', 'B', 'M/J Band 1']
# First nine weeks:  B
# 1
# ['0248013', '6012', '6', 'ANTHONY', 'CASTILLO', 'C', 'C', 'M/J Comprehensive Science 1,Advanced']
# First nine weeks:  C
# 1
# ['0248013', '6012', '6', 'ANTHONY', 'CASTILLO', 'B', 'B', 'M/J United States History, Advanced']
# First nine weeks:  B
# 1
# ['0248013', '6012', '6', 'ANTHONY', 'CASTILLO', 'B', 'B', 'M/J Language Arts 1, Advanced']
# First nine weeks:  B
# 1
# ['0248013', '6012', '6', 'ANTHONY', 'CASTILLO', 'C', 'B', 'M/J Intensive Reading Enrichment(MC) Grade 6']
# First nine weeks:  C
# 2
# ['0248013', '6012', '6', 'ANTHONY', 'CASTILLO', 'B', ' ', 'Business Keyboarding']
# First nine weeks:  B
# Second nine weeks B
# 2
# ['0255576', '6012', '8', 'ANGEL', 'NICOT', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# 0248013 has 2 points
# Second nine weeks A
# 0
# ['0255576', '6012', '8', 'ANGEL', 'NICOT', 'C', 'B', 'M/J Language Arts 3, Advanced']
# First nine weeks:  C
# 1
# ['0255576', '6012', '8', 'ANGEL', 'NICOT', 'B', 'C', 'Geometry Honors']
# First nine weeks:  B
# 0
# ['0255576', '6012', '8', 'ANGEL', 'NICOT', 'B', 'B', 'M/J World History, Advanced']
# First nine weeks:  B
# 0
# ['0255576', '6012', '8', 'ANGEL', 'NICOT', 'A', 'A', 'M/J Writing 1']
# First nine weeks:  A
# 0
# ['0255576', '6012', '8', 'ANGEL', 'NICOT', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 0
# ['0255576', '6012', '8', 'ANGEL', 'NICOT', 'B', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  B
# Second nine weeks B
# 0
# ['0255576', '6012', '8', 'ANGEL', 'NICOT', 'B', 'B', 'Biology 1 Honors']
# First nine weeks:  B
# 0
# ['0255576', '6012', '8', 'ANGEL', 'NICOT', 'B', 'C', 'Algebra 1 Honors']
# First nine weeks:  B
# -1
# ['0255576', '6012', '8', 'ANGEL', 'NICOT', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -1
# ['0256714', '6012', '8', 'CHRISTOPHE', 'PEREZ', 'C', 'C', 'Biology 1 Honors']
# First nine weeks:  C
# 0255576 has -1 points
# 0
# ['0256714', '6012', '8', 'CHRISTOPHE', 'PEREZ', 'B', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  B
# Second nine weeks B
# 0
# ['0256714', '6012', '8', 'CHRISTOPHE', 'PEREZ', 'B', ' ', 'Exploration of Technical Design Technology and Career Planning']
# First nine weeks:  B
# Second nine weeks B
# 0
# ['0256714', '6012', '8', 'CHRISTOPHE', 'PEREZ', ' ', 'A', 'Fundamentals of Web and Software Development']
# First nine weeks:
# 0
# ['0256714', '6012', '8', 'CHRISTOPHE', 'PEREZ', 'C', 'D', 'M/J Language Arts 3, Advanced']
# First nine weeks:  C
# -1
# ['0256714', '6012', '8', 'CHRISTOPHE', 'PEREZ', 'C', 'C', 'Algebra 1 Honors']
# First nine weeks:  C
# -1
# ['0256714', '6012', '8', 'CHRISTOPHE', 'PEREZ', 'B', 'C', 'M/J World History, Advanced']
# First nine weeks:  B
# -2
# ['0256714', '6012', '8', 'CHRISTOPHE', 'PEREZ', 'C', 'C', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# -2
# ['0256714', '6012', '8', 'CHRISTOPHE', 'PEREZ', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# -2
# ['0256714', '6012', '8', 'CHRISTOPHE', 'PEREZ', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# -2
# ['0256714', '6012', '8', 'CHRISTOPHE', 'PEREZ', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -2
# ['0257227', '6012', '8', 'GABRIEL', 'RODRIGUEZ', ' ', 'A', 'Fundamentals of Web and Software Development']
# First nine weeks:
# 0256714 has -2 points
# 0
# ['0257227', '6012', '8', 'GABRIEL', 'RODRIGUEZ', 'A', 'A', 'Biology 1 Honors']
# First nine weeks:  A
# 0
# ['0257227', '6012', '8', 'GABRIEL', 'RODRIGUEZ', 'A', 'A', 'M/J Three-Dimensional Studio Art 1']
# First nine weeks:  A
# 0
# ['0257227', '6012', '8', 'GABRIEL', 'RODRIGUEZ', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0257227', '6012', '8', 'GABRIEL', 'RODRIGUEZ', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0257227', '6012', '8', 'GABRIEL', 'RODRIGUEZ', 'A', 'A', 'M/J Language Arts 3, Advanced']
# First nine weeks:  A
# 0
# ['0257227', '6012', '8', 'GABRIEL', 'RODRIGUEZ', 'A', 'A', 'Algebra 1 Honors']
# First nine weeks:  A
# 0
# ['0257227', '6012', '8', 'GABRIEL', 'RODRIGUEZ', 'A', 'A', 'M/J World History, Advanced']
# First nine weeks:  A
# 0
# ['0257227', '6012', '8', 'GABRIEL', 'RODRIGUEZ', 'A', ' ', 'Exploration of Technical Design Technology and Career Planning']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0257227', '6012', '8', 'GABRIEL', 'RODRIGUEZ', 'A', 'A', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  A
# 0
# ['0258136', '6012', '8', 'NATHAN', 'ZELEDON', 'B', ' ', 'Exploration of Technical Design Technology and Career Planning']
# First nine weeks:  B
# 0257227 has 0 points
# Second nine weeks B
# 0
# ['0258136', '6012', '8', 'NATHAN', 'ZELEDON', ' ', ' ', 'Speech Therapy: 6-8']
# First nine weeks:
# 0
# ['0258136', '6012', '8', 'NATHAN', 'ZELEDON', 'C', 'C', 'Biology 1 Honors']
# First nine weeks:  C
# 0
# ['0258136', '6012', '8', 'NATHAN', 'ZELEDON', 'C', 'C', 'M/J Language Arts 3, Advanced']
# First nine weeks:  C
# 0
# ['0258136', '6012', '8', 'NATHAN', 'ZELEDON', 'C', 'C', 'Algebra 1 Honors']
# First nine weeks:  C
# 0
# ['0258136', '6012', '8', 'NATHAN', 'ZELEDON', 'B', 'B', 'Learning Strategies: 6-8']
# First nine weeks:  B
# 0
# ['0258136', '6012', '8', 'NATHAN', 'ZELEDON', 'D', 'C', 'M/J World History, Advanced']
# First nine weeks:  D
# 1
# ['0258136', '6012', '8', 'NATHAN', 'ZELEDON', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 1
# ['0258136', '6012', '8', 'NATHAN', 'ZELEDON', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 1
# ['0258136', '6012', '8', 'NATHAN', 'ZELEDON', 'C', 'D', 'Spanish for Spanish Speakers 1']
# First nine weeks:  C
# 0
# ['0258136', '6012', '8', 'NATHAN', 'ZELEDON', ' ', 'B', 'Fundamentals of Web and Software Development']
# First nine weeks:
# 0
# ['0260006', '6012', '8', 'LILIANA', 'BOZA', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# 0258136 has 0 points
# Second nine weeks A
# 0
# ['0260006', '6012', '8', 'LILIANA', 'BOZA', 'A', 'A', 'Biology 1 Honors, Gifted']
# First nine weeks:  A
# 0
# ['0260006', '6012', '8', 'LILIANA', 'BOZA', 'A', 'A', 'Spanish for Spanish Speakers 3 Honors']
# First nine weeks:  A
# 0
# ['0260006', '6012', '8', 'LILIANA', 'BOZA', 'B', 'B', 'Algebra 1 Honors Gifted']
# First nine weeks:  B
# 0
# ['0260006', '6012', '8', 'LILIANA', 'BOZA', 'A', 'A', 'M/J World History, Advanced']
# First nine weeks:  A
# 0
# ['0260006', '6012', '8', 'LILIANA', 'BOZA', 'A', 'A', 'Geometry Honors, Gifted']
# First nine weeks:  A
# 0
# ['0260006', '6012', '8', 'LILIANA', 'BOZA', 'A', 'A', 'M/J Research 1']
# First nine weeks:  A
# 0
# ['0260006', '6012', '8', 'LILIANA', 'BOZA', 'A', 'A', 'M/J Language Arts 3,Advanced/Gifted']
# First nine weeks:  A
# 0
# ['0260006', '6012', '8', 'LILIANA', 'BOZA', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0260455', '6012', '7', 'ANGEL', 'LAREDO', 'C', 'B', 'M/J Comprehensive Science 2']
# First nine weeks:  C
# 0260006 has 0 points
# 1
# ['0260455', '6012', '7', 'ANGEL', 'LAREDO', 'D', 'D', 'M/J Grade 7 Mathematics']
# First nine weeks:  D
# 1
# ['0260455', '6012', '7', 'ANGEL', 'LAREDO', 'C', 'C', 'M/J Intensive Reading (MC) Grade 7']
# First nine weeks:  C
# 1
# ['0260455', '6012', '7', 'ANGEL', 'LAREDO', 'D', 'F', 'Italian 1']
# First nine weeks:  D
# 0
# ['0260455', '6012', '7', 'ANGEL', 'LAREDO', 'D', 'C', 'M/J Civics']
# First nine weeks:  D
# 1
# ['0260455', '6012', '7', 'ANGEL', 'LAREDO', 'B', 'C', 'M/J Language Arts 2']
# First nine weeks:  B
# 0
# ['0260455', '6012', '7', 'ANGEL', 'LAREDO', 'B', 'B', 'Learning Strategies: 6-8']
# First nine weeks:  B
# 0
# ['0260455', '6012', '7', 'ANGEL', 'LAREDO', ' ', 'A', 'M/J Team Sports - Grade 7']
# First nine weeks:
# 0
# ['0260455', '6012', '7', 'ANGEL', 'LAREDO', 'A', ' ', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0268657', '6012', '8', 'PAMELA', 'SEVILLA', 'B', 'B', 'M/J Writing 1']
# First nine weeks:  B
# 0260455 has 0 points
# 0
# ['0268657', '6012', '8', 'PAMELA', 'SEVILLA', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0268657', '6012', '8', 'PAMELA', 'SEVILLA', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 0
# ['0268657', '6012', '8', 'PAMELA', 'SEVILLA', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0268657', '6012', '8', 'PAMELA', 'SEVILLA', 'C', 'C', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# 0
# ['0268657', '6012', '8', 'PAMELA', 'SEVILLA', 'C', 'B', 'M/J Intensive Mathematics (Grade 8)']
# First nine weeks:  C
# 1
# ['0268657', '6012', '8', 'PAMELA', 'SEVILLA', 'C', 'B', 'M/J Language Arts 3']
# First nine weeks:  C
# 2
# ['0268657', '6012', '8', 'PAMELA', 'SEVILLA', 'B', 'C', 'Physical Science Honors']
# First nine weeks:  B
# 1
# ['0268657', '6012', '8', 'PAMELA', 'SEVILLA', 'C', 'C', 'M/J World History']
# First nine weeks:  C
# 1
# ['0268657', '6012', '8', 'PAMELA', 'SEVILLA', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 1
# ['0274707', '6012', '8', 'KENNY', 'MANRESA', 'B', 'B', 'Biology 1 Honors']
# First nine weeks:  B
# 0268657 has 1 points
# 0
# ['0274707', '6012', '8', 'KENNY', 'MANRESA', 'B', 'B', 'M/J World History, Advanced']
# First nine weeks:  B
# 0
# ['0274707', '6012', '8', 'KENNY', 'MANRESA', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 0
# ['0274707', '6012', '8', 'KENNY', 'MANRESA', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0274707', '6012', '8', 'KENNY', 'MANRESA', 'C', 'B', 'Algebra 1 Honors']
# First nine weeks:  C
# 1
# ['0274707', '6012', '8', 'KENNY', 'MANRESA', 'C', 'C', 'M/J Language Arts 3, Advanced']
# First nine weeks:  C
# 1
# ['0274707', '6012', '8', 'KENNY', 'MANRESA', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# 1
# ['0274707', '6012', '8', 'KENNY', 'MANRESA', 'B', 'B', 'M/J Writing 1']
# First nine weeks:  B
# 1
# ['0274707', '6012', '8', 'KENNY', 'MANRESA', 'C', 'B', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# 2
# ['0274707', '6012', '8', 'KENNY', 'MANRESA', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 2
# ['0285104', '6012', '8', 'WILMER', 'MEJIA', 'D', 'C', 'M/J Language Arts 3']
# First nine weeks:  D
# 0274707 has 2 points
# 1
# ['0285104', '6012', '8', 'WILMER', 'MEJIA', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 1
# ['0285104', '6012', '8', 'WILMER', 'MEJIA', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 1
# ['0285104', '6012', '8', 'WILMER', 'MEJIA', 'C', 'F', 'M/J Intensive Reading (MC) Grade 8']
# First nine weeks:  C
# -1
# ['0285104', '6012', '8', 'WILMER', 'MEJIA', 'D', 'D', 'Algebra 1 Honors']
# First nine weeks:  D
# -1
# ['0285104', '6012', '8', 'WILMER', 'MEJIA', 'C', 'D', 'Physical Science Honors']
# First nine weeks:  C
# -2
# ['0285104', '6012', '8', 'WILMER', 'MEJIA', 'D', 'F', 'M/J World History']
# First nine weeks:  D
# -3
# ['0285104', '6012', '8', 'WILMER', 'MEJIA', 'D', 'D', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  D
# -3
# ['0285104', '6012', '8', 'WILMER', 'MEJIA', 'B', 'C', 'Learning Strategies: 6-8']
# First nine weeks:  B
# -4
# ['0290179', '6012', '8', 'EDIS', 'BARRIOS', 'C', 'C', 'M/J Language Arts 3,Advanced/Gifted']
# First nine weeks:  C
# 0285104 has -4 points
# 0
# ['0290179', '6012', '8', 'EDIS', 'BARRIOS', ' ', 'B', 'Exploring Technology']
# First nine weeks:
# 0
# ['0290179', '6012', '8', 'EDIS', 'BARRIOS', 'C', 'C', 'Biology 1 Honors, Gifted']
# First nine weeks:  C
# 0
# ['0290179', '6012', '8', 'EDIS', 'BARRIOS', 'B', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  B
# Second nine weeks B
# 0
# ['0290179', '6012', '8', 'EDIS', 'BARRIOS', 'C', 'C', 'M/J World History, Advanced, Gifted']
# First nine weeks:  C
# 0
# ['0290179', '6012', '8', 'EDIS', 'BARRIOS', 'B', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  B
# Second nine weeks B
# 0
# ['0290179', '6012', '8', 'EDIS', 'BARRIOS', 'B', 'C', 'Algebra 1 Honors Gifted']
# First nine weeks:  B
# -1
# ['0290179', '6012', '8', 'EDIS', 'BARRIOS', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -1
# ['0290179', '6012', '8', 'EDIS', 'BARRIOS', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# -1
# ['0290179', '6012', '8', 'EDIS', 'BARRIOS', 'B', 'B', 'Spanish for Spanish Speakers 1']
# First nine weeks:  B
# -1
# ['0290179', '6012', '8', 'EDIS', 'BARRIOS', 'A', ' ', 'Exploration of Robotics Technologyand Career Planning']
# First nine weeks:  A
# Second nine weeks A
# -1
# ['0295292', '6012', '8', 'DAYANA', 'LOPEZ', 'B', 'A', 'Biology 1 Honors']
# First nine weeks:  B
# 0290179 has -1 points
# 1
# ['0295292', '6012', '8', 'DAYANA', 'LOPEZ', 'B', 'B', 'Italian 2']
# First nine weeks:  B
# 1
# ['0295292', '6012', '8', 'DAYANA', 'LOPEZ', 'B', 'A', 'M/J Language Arts 3, Advanced']
# First nine weeks:  B
# 2
# ['0295292', '6012', '8', 'DAYANA', 'LOPEZ', 'A', 'A', 'M/J Writing 1']
# First nine weeks:  A
# 2
# ['0295292', '6012', '8', 'DAYANA', 'LOPEZ', 'A', 'C', 'Geometry Honors']
# First nine weeks:  A
# 0
# ['0295292', '6012', '8', 'DAYANA', 'LOPEZ', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0295292', '6012', '8', 'DAYANA', 'LOPEZ', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0295292', '6012', '8', 'DAYANA', 'LOPEZ', 'A', 'A', 'Algebra 1 Honors']
# First nine weeks:  A
# 0
# ['0295292', '6012', '8', 'DAYANA', 'LOPEZ', 'A', 'A', 'M/J World History, Advanced']
# First nine weeks:  A
# 0
# ['0295311', '6012', '8', 'NATALIE', 'LAHERA', 'B', 'B', 'Spanish for Spanish Speakers 3 Honors']
# First nine weeks:  B
# 0295292 has 0 points
# 0
# ['0295311', '6012', '8', 'NATALIE', 'LAHERA', 'B', 'B', 'M/J Language Arts 3, Advanced']
# First nine weeks:  B
# 0
# ['0295311', '6012', '8', 'NATALIE', 'LAHERA', 'B', 'A', 'M/J Writing 1']
# First nine weeks:  B
# 1
# ['0295311', '6012', '8', 'NATALIE', 'LAHERA', 'C', 'B', 'Algebra 1 Honors']
# First nine weeks:  C
# 2
# ['0295311', '6012', '8', 'NATALIE', 'LAHERA', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 2
# ['0295311', '6012', '8', 'NATALIE', 'LAHERA', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 2
# ['0295311', '6012', '8', 'NATALIE', 'LAHERA', 'B', 'B', 'Biology 1 Honors']
# First nine weeks:  B
# 2
# ['0295311', '6012', '8', 'NATALIE', 'LAHERA', 'C', 'B', 'M/J World History, Advanced']
# First nine weeks:  C
# 3
# ['0295311', '6012', '8', 'NATALIE', 'LAHERA', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# 3
# ['0295311', '6012', '8', 'NATALIE', 'LAHERA', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 3
# ['0296572', '6012', '8', 'STEPHANIE', 'HERNANDEZ', 'C', 'D', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# 0295311 has 3 points
# -1
# ['0296572', '6012', '8', 'STEPHANIE', 'HERNANDEZ', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -1
# ['0296572', '6012', '8', 'STEPHANIE', 'HERNANDEZ', 'B', 'B', 'M/J Intensive Reading Enrichment(MC) Grade 8']
# First nine weeks:  B
# -1
# ['0296572', '6012', '8', 'STEPHANIE', 'HERNANDEZ', 'C', 'C', 'M/J Intensive Mathematics (Grade 8)']
# First nine weeks:  C
# -1
# ['0296572', '6012', '8', 'STEPHANIE', 'HERNANDEZ', 'B', 'B', 'Biology 1 Honors']
# First nine weeks:  B
# -1
# ['0296572', '6012', '8', 'STEPHANIE', 'HERNANDEZ', 'C', 'C', 'M/J World History, Advanced']
# First nine weeks:  C
# -1
# ['0296572', '6012', '8', 'STEPHANIE', 'HERNANDEZ', 'C', 'C', 'M/J Language Arts 3']
# First nine weeks:  C
# -1
# ['0296572', '6012', '8', 'STEPHANIE', 'HERNANDEZ', 'C', 'C', 'French 2']
# First nine weeks:  C
# -1
# ['0296572', '6012', '8', 'STEPHANIE', 'HERNANDEZ', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# -1
# ['0297879', '6012', '8', 'JAVIER', 'LOPEZ', ' ', 'A', 'Fundamentals of Web and Software Development']
# First nine weeks:
# 0296572 has -1 points
# 0
# ['0297879', '6012', '8', 'JAVIER', 'LOPEZ', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 0
# ['0297879', '6012', '8', 'JAVIER', 'LOPEZ', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0297879', '6012', '8', 'JAVIER', 'LOPEZ', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0297879', '6012', '8', 'JAVIER', 'LOPEZ', 'A', ' ', 'Exploration of Technical Design Technology and Career Planning']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0297879', '6012', '8', 'JAVIER', 'LOPEZ', 'B', 'B', 'Biology 1 Honors']
# First nine weeks:  B
# 0
# ['0297879', '6012', '8', 'JAVIER', 'LOPEZ', 'B', 'B', 'Algebra 1 Honors']
# First nine weeks:  B
# 0
# ['0297879', '6012', '8', 'JAVIER', 'LOPEZ', 'A', 'A', 'M/J Research 1']
# First nine weeks:  A
# 0
# ['0297879', '6012', '8', 'JAVIER', 'LOPEZ', 'C', 'B', 'M/J World History, Advanced']
# First nine weeks:  C
# 1
# ['0297879', '6012', '8', 'JAVIER', 'LOPEZ', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 1
# ['0297879', '6012', '8', 'JAVIER', 'LOPEZ', 'C', 'C', 'M/J Language Arts 3, Advanced']
# First nine weeks:  C
# 1
# ['0299038', '6012', '8', 'ASHLEE', 'GOMEZ', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# 0297879 has 1 points
# Second nine weeks A
# 0
# ['0299038', '6012', '8', 'ASHLEE', 'GOMEZ', 'A', 'A', 'M/J Dance 2']
# First nine weeks:  A
# 0
# ['0299038', '6012', '8', 'ASHLEE', 'GOMEZ', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 0
# ['0299038', '6012', '8', 'ASHLEE', 'GOMEZ', 'D', 'D', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  D
# 0
# ['0299038', '6012', '8', 'ASHLEE', 'GOMEZ', 'C', 'D', 'M/J World History']
# First nine weeks:  C
# -1
# ['0299038', '6012', '8', 'ASHLEE', 'GOMEZ', 'B', 'D', 'M/J Intensive Reading (MC) Grade 8']
# First nine weeks:  B
# -3
# ['0299038', '6012', '8', 'ASHLEE', 'GOMEZ', 'B', 'C', 'M/J Comprehensive Science 3']
# First nine weeks:  B
# -4
# ['0299038', '6012', '8', 'ASHLEE', 'GOMEZ', 'C', 'D', 'M/J Language Arts 3']
# First nine weeks:  C
# -5
# ['0299038', '6012', '8', 'ASHLEE', 'GOMEZ', 'C', 'D', 'M/J Intensive Mathematics (Grade 8)']
# First nine weeks:  C
# -6
# ['0299110', '6012', '8', 'KELLY', 'BOSCH', 'D', 'F', 'Algebra 1 Honors']
# First nine weeks:  D
# 0299038 has -6 points
# -1
# ['0299110', '6012', '8', 'KELLY', 'BOSCH', 'C', 'C', 'Spanish for Spanish Speakers 3 Honors']
# First nine weeks:  C
# -1
# ['0299110', '6012', '8', 'KELLY', 'BOSCH', 'B', 'B', 'Biology 1 Honors, Gifted']
# First nine weeks:  B
# -1
# ['0299110', '6012', '8', 'KELLY', 'BOSCH', 'A', 'A', 'M/J Dance 2']
# First nine weeks:  A
# -1
# ['0299110', '6012', '8', 'KELLY', 'BOSCH', 'B', 'B', 'M/J World History, Advanced, Gifted']
# First nine weeks:  B
# -1
# ['0299110', '6012', '8', 'KELLY', 'BOSCH', 'B', 'A', 'M/J Writing 1']
# First nine weeks:  B
# 0
# ['0299110', '6012', '8', 'KELLY', 'BOSCH', 'D', 'F', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  D
# -1
# ['0299110', '6012', '8', 'KELLY', 'BOSCH', 'B', 'B', 'M/J Language Arts 3,Advanced/Gifted']
# First nine weeks:  B
# -1
# ['0299507', '6012', '8', 'MARBELYS', 'PEREZ', 'B', 'B', 'M/J Writing 1']
# First nine weeks:  B
# 0299110 has -1 points
# 0
# ['0299507', '6012', '8', 'MARBELYS', 'PEREZ', 'B', 'B', 'M/J World History, Advanced']
# First nine weeks:  B
# 0
# ['0299507', '6012', '8', 'MARBELYS', 'PEREZ', 'A', 'C', 'Physical Science Honors']
# First nine weeks:  A
# -2
# ['0299507', '6012', '8', 'MARBELYS', 'PEREZ', 'B', 'B', 'M/J Language Arts 3, Advanced']
# First nine weeks:  B
# -2
# ['0299507', '6012', '8', 'MARBELYS', 'PEREZ', 'B', 'B', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  B
# -2
# ['0299507', '6012', '8', 'MARBELYS', 'PEREZ', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# -2
# ['0299507', '6012', '8', 'MARBELYS', 'PEREZ', 'B', 'B', 'Algebra 1 Honors']
# First nine weeks:  B
# -2
# ['0299507', '6012', '8', 'MARBELYS', 'PEREZ', 'B', 'B', 'Spanish for Spanish Speakers 1']
# First nine weeks:  B
# -2
# ['0299507', '6012', '8', 'MARBELYS', 'PEREZ', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -2
# ['0299566', '6012', '7', 'BRYAN', 'NARDO', 'A', ' ', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:  A
# 0299507 has -2 points
# Second nine weeks A
# 0
# ['0299566', '6012', '7', 'BRYAN', 'NARDO', ' ', 'A', 'M/J Team Sports - Grade 7']
# First nine weeks:
# 0
# ['0299566', '6012', '7', 'BRYAN', 'NARDO', 'A', 'A', 'M/J Writing 1']
# First nine weeks:  A
# 0
# ['0299566', '6012', '7', 'BRYAN', 'NARDO', 'B', 'B', 'M/J Language Arts 2, Advanced']
# First nine weeks:  B
# 0
# ['0299566', '6012', '7', 'BRYAN', 'NARDO', 'B', 'C', 'Spanish for Spanish Speakers 1']
# First nine weeks:  B
# -1
# ['0299566', '6012', '7', 'BRYAN', 'NARDO', 'C', 'B', 'M/J Grade 7 Mathematics Advanced']
# First nine weeks:  C
# 0
# ['0299566', '6012', '7', 'BRYAN', 'NARDO', 'B', 'B', 'M/J Civics, Advanced']
# First nine weeks:  B
# 0
# ['0299566', '6012', '7', 'BRYAN', 'NARDO', 'B', ' ', 'Exploring Technology and Career Planning']
# First nine weeks:  B
# Second nine weeks B
# 0
# ['0299566', '6012', '7', 'BRYAN', 'NARDO', ' ', 'A', 'Introduction to Technology']
# First nine weeks:
# 0
# ['0299566', '6012', '7', 'BRYAN', 'NARDO', 'A', 'B', 'Physical Science Honors']
# First nine weeks:  A
# -1
# ['0300698', '6012', '8', 'COLIN', 'VEGA', 'A', 'A', 'M/J Writing 1']
# First nine weeks:  A
# 0299566 has -1 points
# 0
# ['0300698', '6012', '8', 'COLIN', 'VEGA', 'A', 'A', 'Geometry Honors, Gifted']
# First nine weeks:  A
# 0
# ['0300698', '6012', '8', 'COLIN', 'VEGA', 'A', 'A', 'Biology 1 Honors, Gifted']
# First nine weeks:  A
# 0
# ['0300698', '6012', '8', 'COLIN', 'VEGA', 'A', 'A', 'M/J World History, Advanced, Gifted']
# First nine weeks:  A
# 0
# ['0300698', '6012', '8', 'COLIN', 'VEGA', 'A', 'A', 'M/J Language Arts 3,Advanced/Gifted']
# First nine weeks:  A
# 0
# ['0300698', '6012', '8', 'COLIN', 'VEGA', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0300698', '6012', '8', 'COLIN', 'VEGA', 'A', 'A', 'Algebra 1 Honors Gifted']
# First nine weeks:  A
# 0
# ['0300698', '6012', '8', 'COLIN', 'VEGA', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0300698', '6012', '8', 'COLIN', 'VEGA', 'A', 'A', 'M/J Research 1']
# First nine weeks:  A
# 0
# ['0301025', '6012', '7', 'ROSA', 'ZAVALA', 'B', 'B', 'Physical Science Honors Gifted']
# First nine weeks:  B
# 0300698 has 0 points
# 0
# ['0301025', '6012', '7', 'ROSA', 'ZAVALA', 'A', ' ', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0301025', '6012', '7', 'ROSA', 'ZAVALA', ' ', 'A', 'M/J Team Sports - Grade 7']
# First nine weeks:
# 0
# ['0301025', '6012', '7', 'ROSA', 'ZAVALA', 'B', 'B', 'M/J Language Arts 2,Advanced/Gifted']
# First nine weeks:  B
# 0
# ['0301025', '6012', '7', 'ROSA', 'ZAVALA', 'A', ' ', 'Exploration of Technical Design Technology and Career Planning']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0301025', '6012', '7', 'ROSA', 'ZAVALA', 'A', 'A', 'M/J Writing 1']
# First nine weeks:  A
# 0
# ['0301025', '6012', '7', 'ROSA', 'ZAVALA', 'A', 'A', 'M/J Civics, Advanced, Gifted']
# First nine weeks:  A
# 0
# ['0301025', '6012', '7', 'ROSA', 'ZAVALA', 'C', 'B', 'M/J Grade 7 Mathematics Advanced, Gifted']
# First nine weeks:  C
# 1
# ['0301025', '6012', '7', 'ROSA', 'ZAVALA', 'C', 'B', 'French 1']
# First nine weeks:  C
# 2
# ['0301025', '6012', '7', 'ROSA', 'ZAVALA', ' ', 'A', 'Fundamentals of Web and Software Development']
# First nine weeks:
# 2
# ['0302715', '6012', '8', 'JOHANN', 'MUNOZ', 'A', ' ', 'Exploration of Technical Design Technology and Career Planning']
# First nine weeks:  A
# 0301025 has 2 points
# Second nine weeks A
# 0
# ['0302715', '6012', '8', 'JOHANN', 'MUNOZ', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0302715', '6012', '8', 'JOHANN', 'MUNOZ', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 0
# ['0302715', '6012', '8', 'JOHANN', 'MUNOZ', 'B', 'C', 'Geometry Honors, Gifted']
# First nine weeks:  B
# -1
# ['0302715', '6012', '8', 'JOHANN', 'MUNOZ', ' ', 'A', 'Fundamentals of Web and Software Development']
# First nine weeks:
# -1
# ['0302715', '6012', '8', 'JOHANN', 'MUNOZ', 'A', 'A', 'Biology 1 Honors, Gifted']
# First nine weeks:  A
# -1
# ['0302715', '6012', '8', 'JOHANN', 'MUNOZ', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# -1
# ['0302715', '6012', '8', 'JOHANN', 'MUNOZ', 'B', 'A', 'Algebra 1 Honors Gifted']
# First nine weeks:  B
# 0
# ['0302715', '6012', '8', 'JOHANN', 'MUNOZ', 'B', 'B', 'M/J Language Arts 3,Advanced/Gifted']
# First nine weeks:  B
# 0
# ['0302715', '6012', '8', 'JOHANN', 'MUNOZ', 'B', 'B', 'M/J World History, Advanced, Gifted']
# First nine weeks:  B
# 0
# ['0302715', '6012', '8', 'JOHANN', 'MUNOZ', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0304218', '6012', '8', 'SEBASTIAN', 'MEJIA', 'C', 'C', 'M/J Language Arts 3, Advanced']
# First nine weeks:  C
# 0302715 has 0 points
# 0
# ['0304218', '6012', '8', 'SEBASTIAN', 'MEJIA', 'D', 'F', 'Spanish for Spanish Speakers 3 Honors']
# First nine weeks:  D
# -1
# ['0304218', '6012', '8', 'SEBASTIAN', 'MEJIA', 'B', 'B', 'Algebra 1 Honors']
# First nine weeks:  B
# -1
# ['0304218', '6012', '8', 'SEBASTIAN', 'MEJIA', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -1
# ['0304218', '6012', '8', 'SEBASTIAN', 'MEJIA', 'A', 'B', 'M/J Writing 1']
# First nine weeks:  A
# -2
# ['0304218', '6012', '8', 'SEBASTIAN', 'MEJIA', 'C', 'C', 'Geometry Honors']
# First nine weeks:  C
# -2
# ['0304218', '6012', '8', 'SEBASTIAN', 'MEJIA', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# -2
# ['0304218', '6012', '8', 'SEBASTIAN', 'MEJIA', 'B', 'B', 'M/J World History, Advanced']
# First nine weeks:  B
# -2
# ['0304218', '6012', '8', 'SEBASTIAN', 'MEJIA', 'B', 'B', 'Biology 1 Honors']
# First nine weeks:  B
# -2
# ['0304712', '6012', '8', 'SERIAH', 'ST-REMY', 'B', 'A', 'Biology 1 Honors']
# First nine weeks:  B
# 0304218 has -2 points
# 1
# ['0304712', '6012', '8', 'SERIAH', 'ST-REMY', 'C', 'B', 'Algebra 1 Honors']
# First nine weeks:  C
# 2
# ['0304712', '6012', '8', 'SERIAH', 'ST-REMY', 'B', 'B', 'French 2']
# First nine weeks:  B
# 2
# ['0304712', '6012', '8', 'SERIAH', 'ST-REMY', 'C', 'B', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# 3
# ['0304712', '6012', '8', 'SERIAH', 'ST-REMY', 'A', 'B', 'M/J Dance 2']
# First nine weeks:  A
# 2
# ['0304712', '6012', '8', 'SERIAH', 'ST-REMY', 'A', 'A', 'M/J Chorus 2']
# First nine weeks:  A
# 2
# ['0304712', '6012', '8', 'SERIAH', 'ST-REMY', 'B', 'A', 'M/J World History, Advanced']
# First nine weeks:  B
# 3
# ['0304712', '6012', '8', 'SERIAH', 'ST-REMY', 'B', 'B', 'M/J Language Arts 3, Advanced']
# First nine weeks:  B
# 3
# ['0305931', '6012', '7', 'ALEXANDER', 'REDONDO', 'A', 'C', 'M/J Research 1']
# First nine weeks:  A
# 0304712 has 3 points
# -2
# ['0305931', '6012', '7', 'ALEXANDER', 'REDONDO', ' ', 'A', 'M/J Team Sports - Grade 7']
# First nine weeks:
# -2
# ['0305931', '6012', '7', 'ALEXANDER', 'REDONDO', 'C', 'C', 'M/J Civics']
# First nine weeks:  C
# -2
# ['0305931', '6012', '7', 'ALEXANDER', 'REDONDO', 'B', 'B', 'M/J Language Arts 2']
# First nine weeks:  B
# -2
# ['0305931', '6012', '7', 'ALEXANDER', 'REDONDO', 'C', 'C', 'M/J Intensive Reading Enrichment(MC) Grade 7']
# First nine weeks:  C
# -2
# ['0305931', '6012', '7', 'ALEXANDER', 'REDONDO', 'C', 'B', 'M/J Comprehensive Science 2']
# First nine weeks:  C
# -1
# ['0305931', '6012', '7', 'ALEXANDER', 'REDONDO', 'A', ' ', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:  A
# Second nine weeks A
# -1
# ['0305931', '6012', '7', 'ALEXANDER', 'REDONDO', 'C', 'F', 'Spanish for Spanish Speakers 1']
# First nine weeks:  C
# -3
# ['0305931', '6012', '7', 'ALEXANDER', 'REDONDO', 'B', 'C', 'M/J Grade 7 Mathematics']
# First nine weeks:  B
# -4
# ['0307468', '6012', '7', 'SAMANTHA', 'VALES', 'C', 'C', 'M/J Intensive Reading (MC) Grade 7']
# First nine weeks:  C
# 0305931 has -4 points
# 0
# ['0307468', '6012', '7', 'SAMANTHA', 'VALES', 'C', 'C', 'M/J Civics']
# First nine weeks:  C
# 0
# ['0307468', '6012', '7', 'SAMANTHA', 'VALES', 'D', 'F', 'M/J Grade 7 Mathematics']
# First nine weeks:  D
# -1
# ['0307468', '6012', '7', 'SAMANTHA', 'VALES', 'C', 'D', 'M/J Intensive Mathematics (Grade 7)']
# First nine weeks:  C
# -2
# ['0307468', '6012', '7', 'SAMANTHA', 'VALES', 'A', ' ', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:  A
# Second nine weeks A
# -2
# ['0307468', '6012', '7', 'SAMANTHA', 'VALES', 'C', 'F', 'Spanish for Spanish Speakers 1']
# First nine weeks:  C
# -4
# ['0307468', '6012', '7', 'SAMANTHA', 'VALES', 'C', 'D', 'M/J Comprehensive Science 2']
# First nine weeks:  C
# -5
# ['0307468', '6012', '7', 'SAMANTHA', 'VALES', ' ', 'A', 'M/J Team Sports - Grade 7']
# First nine weeks:
# -5
# ['0307468', '6012', '7', 'SAMANTHA', 'VALES', 'C', 'C', 'M/J Language Arts 2']
# First nine weeks:  C
# -5
# ['0307925', '6012', '8', 'BRYANT', 'PADRON', 'C', 'C', 'Physical Science Honors']
# First nine weeks:  C
# 0307468 has -5 points
# 0
# ['0307925', '6012', '8', 'BRYANT', 'PADRON', 'C', 'C', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# 0
# ['0307925', '6012', '8', 'BRYANT', 'PADRON', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0307925', '6012', '8', 'BRYANT', 'PADRON', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0307925', '6012', '8', 'BRYANT', 'PADRON', 'C', 'C', 'M/J World History']
# First nine weeks:  C
# 0
# ['0307925', '6012', '8', 'BRYANT', 'PADRON', 'B', 'C', 'M/J Intensive Reading (MC) Grade 8']
# First nine weeks:  B
# -1
# ['0307925', '6012', '8', 'BRYANT', 'PADRON', ' ', ' ', 'Language Therapy: 6-8']
# First nine weeks:
# -1
# ['0307925', '6012', '8', 'BRYANT', 'PADRON', 'B', 'C', 'M/J Intensive Mathematics (Grade 8)']
# First nine weeks:  B
# -2
# ['0307925', '6012', '8', 'BRYANT', 'PADRON', 'D', 'C', 'M/J Language Arts 3']
# First nine weeks:  D
# -1
# ['0307925', '6012', '8', 'BRYANT', 'PADRON', 'B', 'C', 'Learning Strategies: 6-8']
# First nine weeks:  B
# -2
# ['0307928', '6012', '8', 'JESMARI', 'HERRERA', 'F', 'F', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  F
# 0307925 has -2 points
# 0
# ['0307928', '6012', '8', 'JESMARI', 'HERRERA', 'B', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  B
# Second nine weeks B
# 0
# ['0307928', '6012', '8', 'JESMARI', 'HERRERA', 'A', 'A', 'M/J Chorus 2']
# First nine weeks:  A
# 0
# ['0307928', '6012', '8', 'JESMARI', 'HERRERA', 'A', 'A', 'M/J Comprehensive Science 3']
# First nine weeks:  A
# 0
# ['0307928', '6012', '8', 'JESMARI', 'HERRERA', 'F', 'F', 'Algebra 1 Honors']
# First nine weeks:  F
# 0
# ['0307928', '6012', '8', 'JESMARI', 'HERRERA', 'C', 'C', 'M/J Language Arts 3, Advanced']
# First nine weeks:  C
# 0
# ['0307928', '6012', '8', 'JESMARI', 'HERRERA', ' ', 'B', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0307928', '6012', '8', 'JESMARI', 'HERRERA', 'B', 'A', 'M/J Writing 1']
# First nine weeks:  B
# 1
# ['0307928', '6012', '8', 'JESMARI', 'HERRERA', 'D', 'C', 'M/J World History, Advanced']
# First nine weeks:  D
# 2
# ['0308357', '6012', '8', 'KEVIN', 'VALIDO', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 0307928 has 2 points
# 0
# ['0308357', '6012', '8', 'KEVIN', 'VALIDO', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0308357', '6012', '8', 'KEVIN', 'VALIDO', 'C', 'B', 'M/J World History, Advanced']
# First nine weeks:  C
# 1
# ['0308357', '6012', '8', 'KEVIN', 'VALIDO', 'C', 'C', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# 1
# ['0308357', '6012', '8', 'KEVIN', 'VALIDO', 'B', 'C', 'M/J Language Arts 3, Advanced']
# First nine weeks:  B
# 0
# ['0308357', '6012', '8', 'KEVIN', 'VALIDO', 'C', 'C', 'Algebra 1 Honors']
# First nine weeks:  C
# 0
# ['0308357', '6012', '8', 'KEVIN', 'VALIDO', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0308357', '6012', '8', 'KEVIN', 'VALIDO', 'C', 'C', 'Italian 2']
# First nine weeks:  C
# 0
# ['0308357', '6012', '8', 'KEVIN', 'VALIDO', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0308357', '6012', '8', 'KEVIN', 'VALIDO', 'B', 'B', 'Biology 1 Honors']
# First nine weeks:  B
# 0
# ['0308359', '6012', '8', 'DEIJEN', 'SEVERINO', 'C', 'C', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# 0308357 has 0 points
# 0
# ['0308359', '6012', '8', 'DEIJEN', 'SEVERINO', 'C', 'C', 'Algebra 1 Honors']
# First nine weeks:  C
# 0
# ['0308359', '6012', '8', 'DEIJEN', 'SEVERINO', 'B', 'B', 'M/J Intensive Reading Enrichment(MC) Grade 8']
# First nine weeks:  B
# 0
# ['0308359', '6012', '8', 'DEIJEN', 'SEVERINO', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 0
# ['0308359', '6012', '8', 'DEIJEN', 'SEVERINO', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0308359', '6012', '8', 'DEIJEN', 'SEVERINO', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0308359', '6012', '8', 'DEIJEN', 'SEVERINO', 'C', 'B', 'M/J World History']
# First nine weeks:  C
# 1
# ['0308359', '6012', '8', 'DEIJEN', 'SEVERINO', 'B', 'B', 'Physical Science Honors']
# First nine weeks:  B
# 1
# ['0308359', '6012', '8', 'DEIJEN', 'SEVERINO', 'B', 'B', 'M/J Language Arts 3']
# First nine weeks:  B
# 1
# ['0308359', '6012', '8', 'DEIJEN', 'SEVERINO', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 1
# ['0310118', '6012', '7', 'ANTHONY', 'REDONDO', 'C', 'C', 'M/J Civics']
# First nine weeks:  C
# 0308359 has 1 points
# 0
# ['0310118', '6012', '7', 'ANTHONY', 'REDONDO', 'C', 'C', 'French 1']
# First nine weeks:  C
# 0
# ['0310118', '6012', '7', 'ANTHONY', 'REDONDO', 'B', 'B', 'M/J Language Arts 2']
# First nine weeks:  B
# 0
# ['0310118', '6012', '7', 'ANTHONY', 'REDONDO', 'B', 'B', 'M/J Two-Dimensional Studio Art 1']
# First nine weeks:  B
# 0
# ['0310118', '6012', '7', 'ANTHONY', 'REDONDO', 'B', 'B', 'M/J Comprehensive Science 2']
# First nine weeks:  B
# 0
# ['0310118', '6012', '7', 'ANTHONY', 'REDONDO', ' ', 'A', 'M/J Team Sports - Grade 7']
# First nine weeks:
# 0
# ['0310118', '6012', '7', 'ANTHONY', 'REDONDO', 'B', 'C', 'M/J Grade 7 Mathematics']
# First nine weeks:  B
# -1
# ['0310118', '6012', '7', 'ANTHONY', 'REDONDO', 'C', 'C', 'M/J Intensive Reading Enrichment(MC) Grade 7']
# First nine weeks:  C
# -1
# ['0310118', '6012', '7', 'ANTHONY', 'REDONDO', 'A', ' ', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:  A
# Second nine weeks A
# -1
# ['0310238', '6012', '8', 'CHAUNCEY', 'GUERRIER', 'D', 'F', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  D
# 0310118 has -1 points
# -1
# ['0310238', '6012', '8', 'CHAUNCEY', 'GUERRIER', 'D', 'F', 'Italian 1']
# First nine weeks:  D
# -2
# ['0310238', '6012', '8', 'CHAUNCEY', 'GUERRIER', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# -2
# ['0310238', '6012', '8', 'CHAUNCEY', 'GUERRIER', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -2
# ['0310238', '6012', '8', 'CHAUNCEY', 'GUERRIER', 'D', 'F', 'Algebra 1 Honors']
# First nine weeks:  D
# -3
# ['0310238', '6012', '8', 'CHAUNCEY', 'GUERRIER', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# -3
# ['0310238', '6012', '8', 'CHAUNCEY', 'GUERRIER', 'D', 'C', 'M/J Language Arts 3']
# First nine weeks:  D
# -2
# ['0310238', '6012', '8', 'CHAUNCEY', 'GUERRIER', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# -2
# ['0310238', '6012', '8', 'CHAUNCEY', 'GUERRIER', 'C', 'C', 'M/J World History']
# First nine weeks:  C
# -2
# ['0310238', '6012', '8', 'CHAUNCEY', 'GUERRIER', 'B', 'A', 'M/J Comprehensive Science 3']
# First nine weeks:  B
# -1
# ['0310567', '6012', '8', 'JAVIER', 'NARVAEZ-HERRER', 'D', 'C', 'Biology 1 Honors']
# First nine weeks:  D
# 0310238 has -1 points
# 1
# ['0310567', '6012', '8', 'JAVIER', 'NARVAEZ-HERRER', 'C', 'B', 'M/J Research 1']
# First nine weeks:  C
# 2
# ['0310567', '6012', '8', 'JAVIER', 'NARVAEZ-HERRER', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# 2
# ['0310567', '6012', '8', 'JAVIER', 'NARVAEZ-HERRER', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 2
# ['0310567', '6012', '8', 'JAVIER', 'NARVAEZ-HERRER', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 2
# ['0310567', '6012', '8', 'JAVIER', 'NARVAEZ-HERRER', 'C', 'B', 'Algebra 1 Honors']
# First nine weeks:  C
# 3
# ['0310567', '6012', '8', 'JAVIER', 'NARVAEZ-HERRER', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 3
# ['0310567', '6012', '8', 'JAVIER', 'NARVAEZ-HERRER', 'B', 'B', 'M/J Writing 1']
# First nine weeks:  B
# 3
# ['0310567', '6012', '8', 'JAVIER', 'NARVAEZ-HERRER', 'C', 'B', 'M/J Language Arts 3, Advanced']
# First nine weeks:  C
# 4
# ['0310567', '6012', '8', 'JAVIER', 'NARVAEZ-HERRER', 'C', 'C', 'M/J World History, Advanced']
# First nine weeks:  C
# 4
# ['0310859', '6012', '8', 'AMANDA', 'CALLEJAS', 'C', 'C', 'M/J Intensive Mathematics (Grade 8)']
# First nine weeks:  C
# 0310567 has 4 points
# 0
# ['0310859', '6012', '8', 'AMANDA', 'CALLEJAS', 'C', 'C', 'Italian 1']
# First nine weeks:  C
# 0
# ['0310859', '6012', '8', 'AMANDA', 'CALLEJAS', 'B', 'B', 'M/J World History']
# First nine weeks:  B
# 0
# ['0310859', '6012', '8', 'AMANDA', 'CALLEJAS', 'A', 'B', 'M/J Dance 1']
# First nine weeks:  A
# -1
# ['0310859', '6012', '8', 'AMANDA', 'CALLEJAS', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# -1
# ['0310859', '6012', '8', 'AMANDA', 'CALLEJAS', 'C', 'B', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# 0
# ['0310859', '6012', '8', 'AMANDA', 'CALLEJAS', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 0
# ['0310859', '6012', '8', 'AMANDA', 'CALLEJAS', 'B', 'A', 'M/J Comprehensive Science 3']
# First nine weeks:  B
# 1
# ['0310859', '6012', '8', 'AMANDA', 'CALLEJAS', 'C', 'C', 'M/J Language Arts 3']
# First nine weeks:  C
# 1
# ['0313670', '6012', '7', 'ALAYN', 'RODRIGUEZ', ' ', 'A', 'M/J Team Sports - Grade 7']
# First nine weeks:
# 0310859 has 1 points
# 0
# ['0313670', '6012', '7', 'ALAYN', 'RODRIGUEZ', 'A', 'B', 'M/J Research 1']
# First nine weeks:  A
# -1
# ['0313670', '6012', '7', 'ALAYN', 'RODRIGUEZ', 'C', 'C', 'M/J Grade 7 Mathematics Advanced']
# First nine weeks:  C
# -1
# ['0313670', '6012', '7', 'ALAYN', 'RODRIGUEZ', 'B', 'B', 'M/J Civics, Advanced']
# First nine weeks:  B
# -1
# ['0313670', '6012', '7', 'ALAYN', 'RODRIGUEZ', 'B', 'D', 'Spanish for Spanish Speakers 1']
# First nine weeks:  B
# -3
# ['0313670', '6012', '7', 'ALAYN', 'RODRIGUEZ', 'B', 'B', 'Physical Science Honors']
# First nine weeks:  B
# -3
# ['0313670', '6012', '7', 'ALAYN', 'RODRIGUEZ', 'B', 'C', 'M/J Language Arts 2, Advanced']
# First nine weeks:  B
# -4
# ['0313670', '6012', '7', 'ALAYN', 'RODRIGUEZ', 'A', 'B', 'M/J Writing 1']
# First nine weeks:  A
# -5
# ['0313670', '6012', '7', 'ALAYN', 'RODRIGUEZ', 'A', ' ', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:  A
# Second nine weeks A
# -5
# ['0313935', '6012', '8', 'MAX', 'ORTIZ', 'B', 'A', 'M/J Two-Dimensional Studio Art 1']
# First nine weeks:  B
# 0313670 has -5 points
# 1
# ['0313935', '6012', '8', 'MAX', 'ORTIZ', 'B', 'C', 'M/J Language Arts 3,Advanced/Gifted']
# First nine weeks:  B
# 0
# ['0313935', '6012', '8', 'MAX', 'ORTIZ', 'C', 'C', 'M/J Intensive Mathematics (Grade 8)']
# First nine weeks:  C
# 0
# ['0313935', '6012', '8', 'MAX', 'ORTIZ', 'C', 'C', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# 0
# ['0313935', '6012', '8', 'MAX', 'ORTIZ', 'C', 'C', 'M/J World History, Advanced, Gifted']
# First nine weeks:  C
# 0
# ['0313935', '6012', '8', 'MAX', 'ORTIZ', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0313935', '6012', '8', 'MAX', 'ORTIZ', 'D', 'D', 'German 1']
# First nine weeks:  D
# 0
# ['0313935', '6012', '8', 'MAX', 'ORTIZ', 'B', 'B', 'Biology 1 Honors, Gifted']
# First nine weeks:  B
# 0
# ['0313935', '6012', '8', 'MAX', 'ORTIZ', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0314762', '6012', '8', 'AMAURY', 'ALVAREZ', 'B', 'B', 'Physical Science Honors']
# First nine weeks:  B
# 0313935 has 0 points
# 0
# ['0314762', '6012', '8', 'AMAURY', 'ALVAREZ', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 0
# ['0314762', '6012', '8', 'AMAURY', 'ALVAREZ', 'A', 'B', 'M/J Theatre 1']
# First nine weeks:  A
# -1
# ['0314762', '6012', '8', 'AMAURY', 'ALVAREZ', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# -1
# ['0314762', '6012', '8', 'AMAURY', 'ALVAREZ', 'C', 'C', 'Algebra 1 Honors']
# First nine weeks:  C
# -1
# ['0314762', '6012', '8', 'AMAURY', 'ALVAREZ', 'B', 'B', 'Spanish for Spanish Speakers 1']
# First nine weeks:  B
# -1
# ['0314762', '6012', '8', 'AMAURY', 'ALVAREZ', 'B', 'C', 'M/J World History, Advanced']
# First nine weeks:  B
# -2
# ['0314762', '6012', '8', 'AMAURY', 'ALVAREZ', 'B', 'C', 'M/J Language Arts 3, Advanced']
# First nine weeks:  B
# -3
# ['0314762', '6012', '8', 'AMAURY', 'ALVAREZ', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -3
# ['0314762', '6012', '8', 'AMAURY', 'ALVAREZ', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# -3
# ['0314988', '6012', '6', 'LEKIAN', 'GONZALEZ', 'B', 'C', 'Spanish for Spanish Speakers 1']
# First nine weeks:  B
# 0314762 has -3 points
# -1
# ...
# First nine weeks:  A
# Second nine weeks A
# 1
# ['0815481', '6012', '8', 'ISABELLA', 'ARREDONDO', ' ', 'B', 'Fundamentals of Web and Software Development']
# First nine weeks:
# 1
# ['0815481', '6012', '8', 'ISABELLA', 'ARREDONDO', 'B', 'C', 'M/J World History']
# First nine weeks:  B
# 0
# ['0815481', '6012', '8', 'ISABELLA', 'ARREDONDO', 'A', 'A', 'M/J Dance 1']
# First nine weeks:  A
# 0
# ['0816728', '6012', '8', 'GABRIELLE', 'PETERSON', 'B', 'B', 'M/J Language Arts 3']
# First nine weeks:  B
# 0815481 has 0 points
# 0
# ['0816728', '6012', '8', 'GABRIELLE', 'PETERSON', 'B', 'A', 'M/J Dance 2']
# First nine weeks:  B
# 1
# ['0816728', '6012', '8', 'GABRIELLE', 'PETERSON', 'B', 'B', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  B
# 1
# ['0816728', '6012', '8', 'GABRIELLE', 'PETERSON', 'B', 'B', 'M/J World History']
# First nine weeks:  B
# 1
# ['0816728', '6012', '8', 'GABRIELLE', 'PETERSON', 'B', 'C', 'M/J Intensive Mathematics (Grade 8)']
# First nine weeks:  B
# 0
# ['0816728', '6012', '8', 'GABRIELLE', 'PETERSON', 'B', 'B', 'Spanish 1']
# First nine weeks:  B
# 0
# ['0816728', '6012', '8', 'GABRIELLE', 'PETERSON', 'B', 'C', 'Physical Science Honors']
# First nine weeks:  B
# -1
# ['0816728', '6012', '8', 'GABRIELLE', 'PETERSON', 'A', 'B', 'M/J Band 1']
# First nine weeks:  A
# -2
# ['0817677', '6012', '8', 'JASON', 'EDGECOMBE', 'B', ' ', 'Exploration of Technical Design Technology and Career Planning']
# First nine weeks:  B
# 0816728 has -2 points
# Second nine weeks B
# 0
# ['0817677', '6012', '8', 'JASON', 'EDGECOMBE', 'B', 'C', 'Spanish 1']
# First nine weeks:  B
# -1
# ['0817677', '6012', '8', 'JASON', 'EDGECOMBE', 'C', 'C', 'M/J World History']
# First nine weeks:  C
# -1
# ['0817677', '6012', '8', 'JASON', 'EDGECOMBE', 'C', 'D', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# -2
# ['0817677', '6012', '8', 'JASON', 'EDGECOMBE', ' ', 'B', 'Fundamentals of Web and Software Development']
# First nine weeks:
# -2
# ['0817677', '6012', '8', 'JASON', 'EDGECOMBE', 'C', 'C', 'M/J Language Arts 3']
# First nine weeks:  C
# -2
# ['0817677', '6012', '8', 'JASON', 'EDGECOMBE', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -2
# ['0817677', '6012', '8', 'JASON', 'EDGECOMBE', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# -2
# ['0817677', '6012', '8', 'JASON', 'EDGECOMBE', 'C', 'C', 'Physical Science Honors']
# First nine weeks:  C
# -2
# ['0817677', '6012', '8', 'JASON', 'EDGECOMBE', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# -2
# ['0817677', '6012', '8', 'JASON', 'EDGECOMBE', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# Second nine weeks A
# -2
# ['0819512', '6012', '8', 'AHMIR', 'BRITT', 'C', 'C', 'M/J Research 1']
# First nine weeks:  C
# 0817677 has -2 points
# 0
# ['0819512', '6012', '8', 'AHMIR', 'BRITT', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0819512', '6012', '8', 'AHMIR', 'BRITT', 'C', 'C', 'M/J Language Arts 3']
# First nine weeks:  C
# 0
# ['0819512', '6012', '8', 'AHMIR', 'BRITT', 'A', 'B', 'M/J World History']
# First nine weeks:  A
# -1
# ['0819512', '6012', '8', 'AHMIR', 'BRITT', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -1
# ['0819512', '6012', '8', 'AHMIR', 'BRITT', 'B', 'B', 'M/J Band 1']
# First nine weeks:  B
# -1
# ['0819512', '6012', '8', 'AHMIR', 'BRITT', 'B', 'B', 'M/J Two-Dimensional Studio Art 1']
# First nine weeks:  B
# -1
# ['0819512', '6012', '8', 'AHMIR', 'BRITT', 'C', 'C', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  C
# -1
# ['0819512', '6012', '8', 'AHMIR', 'BRITT', 'B', 'B', 'M/J Comprehensive Science 3']
# First nine weeks:  B
# -1
# ['0821434', '6012', '6', 'LINDSAY', 'LEE', 'D', 'C', 'M/J Language Arts 1']
# First nine weeks:  D
# 0819512 has -1 points
# 1
# ['0821434', '6012', '6', 'LINDSAY', 'LEE', 'D', 'C', 'M/J United States History']
# First nine weeks:  D
# 2
# ['0821434', '6012', '6', 'LINDSAY', 'LEE', 'B', 'A', 'M/J Two-Dimensional Studio Art 1']
# First nine weeks:  B
# 3
# ['0821434', '6012', '6', 'LINDSAY', 'LEE', 'F', 'D', 'M/J Comprehensive Science 1']
# First nine weeks:  F
# 4
# ['0821434', '6012', '6', 'LINDSAY', 'LEE', 'D', ' ', 'Business Keyboarding']
# First nine weeks:  D
# Second nine weeks D
# 4
# ['0821434', '6012', '6', 'LINDSAY', 'LEE', ' ', 'C', 'Business Keyboarding and Career Planning']
# First nine weeks:
# 4
# ['0821434', '6012', '6', 'LINDSAY', 'LEE', 'D', 'F', 'M/J Intensive Reading Enrichment(MC) Grade 6']
# First nine weeks:  D
# 3
# ['0821434', '6012', '6', 'LINDSAY', 'LEE', 'D', 'D', 'M/J Grade 6 Mathematics']
# First nine weeks:  D
# 3
# ['0821434', '6012', '6', 'LINDSAY', 'LEE', 'B', 'B', 'M/J Dance 1']
# First nine weeks:  B
# 3
# ['0824019', '6012', '6', 'ASHLEY', 'MANZO', 'C', 'C', 'M/J Language Arts 1']
# First nine weeks:  C
# 0821434 has 3 points
# 0
# ['0824019', '6012', '6', 'ASHLEY', 'MANZO', 'C', ' ', 'Business Keyboarding']
# First nine weeks:  C
# Second nine weeks C
# 0
# ['0824019', '6012', '6', 'ASHLEY', 'MANZO', ' ', 'C', 'M/J Intensive Mathematics (Grade 6)']
# First nine weeks:
# 0
# ['0824019', '6012', '6', 'ASHLEY', 'MANZO', ' ', 'B', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:
# 0
# ['0824019', '6012', '6', 'ASHLEY', 'MANZO', 'C', 'C', 'M/J United States History']
# First nine weeks:  C
# 0
# ['0824019', '6012', '6', 'ASHLEY', 'MANZO', 'C', 'D', 'M/J Intensive Reading (MC) Grade 6']
# First nine weeks:  C
# -1
# ['0824019', '6012', '6', 'ASHLEY', 'MANZO', 'C', ' ', 'M/J Fitness - Grade 6']
# First nine weeks:  C
# Second nine weeks C
# -1
# ['0824019', '6012', '6', 'ASHLEY', 'MANZO', 'D', 'F', 'M/J Grade 6 Mathematics']
# First nine weeks:  D
# -2
# ['0824019', '6012', '6', 'ASHLEY', 'MANZO', 'D', 'D', 'M/J Comprehensive Science 1']
# First nine weeks:  D
# -2
# ['0824019', '6012', '6', 'ASHLEY', 'MANZO', ' ', 'D', 'Business Keyboarding and Career Planning']
# First nine weeks:
# -2
# ['0824034', '6012', '6', 'MAYTE', 'LONDRES', 'B', 'C', 'M/J Language Arts 1']
# First nine weeks:  B
# 0824019 has -2 points
# -1
# ['0824034', '6012', '6', 'MAYTE', 'LONDRES', 'B', ' ', 'M/J Fitness - Grade 6']
# First nine weeks:  B
# Second nine weeks B
# -1
# ['0824034', '6012', '6', 'MAYTE', 'LONDRES', 'C', 'B', 'M/J United States History']
# First nine weeks:  C
# 0
# ['0824034', '6012', '6', 'MAYTE', 'LONDRES', 'A', ' ', 'Introduction to Technology']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0824034', '6012', '6', 'MAYTE', 'LONDRES', ' ', 'B', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:
# 0
# ['0824034', '6012', '6', 'MAYTE', 'LONDRES', 'C', 'C', 'M/J Intensive Reading (MC) Grade 6']
# First nine weeks:  C
# 0
# ['0824034', '6012', '6', 'MAYTE', 'LONDRES', ' ', 'A', 'Introduction to Technology and Career Planning']
# First nine weeks:
# 0
# ['0824034', '6012', '6', 'MAYTE', 'LONDRES', ' ', 'D', 'Fundamentals of Web and Software Development']
# First nine weeks:
# 0
# ['0824034', '6012', '6', 'MAYTE', 'LONDRES', 'C', 'C', 'M/J Grade 6 Mathematics']
# First nine weeks:  C
# 0
# ['0824034', '6012', '6', 'MAYTE', 'LONDRES', 'B', ' ', 'Exploration of Technical Design Technology and Career Planning']
# First nine weeks:  B
# Second nine weeks B
# 0
# ['0824034', '6012', '6', 'MAYTE', 'LONDRES', 'D', 'D', 'M/J Comprehensive Science 1']
# First nine weeks:  D
# 0
# ['0824080', '6012', '8', 'CHRISTOPHE', 'NAJARRO', 'A', 'A', 'M/J Chorus 1']
# First nine weeks:  A
# 0824034 has 0 points
# 0
# ['0824080', '6012', '8', 'CHRISTOPHE', 'NAJARRO', 'D', 'F', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  D
# -1
# ['0824080', '6012', '8', 'CHRISTOPHE', 'NAJARRO', 'F', 'D', 'M/J Language Arts 3']
# First nine weeks:  F
# 0
# ['0824080', '6012', '8', 'CHRISTOPHE', 'NAJARRO', 'F', 'F', 'Physical Science Honors']
# First nine weeks:  F
# 0
# ['0824080', '6012', '8', 'CHRISTOPHE', 'NAJARRO', 'B', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  B
# Second nine weeks B
# 0
# ['0824080', '6012', '8', 'CHRISTOPHE', 'NAJARRO', 'D', 'F', 'Spanish for Spanish Speakers 1']
# First nine weeks:  D
# -1
# ['0824080', '6012', '8', 'CHRISTOPHE', 'NAJARRO', 'F', 'F', 'M/J World History']
# First nine weeks:  F
# -1
# ['0824080', '6012', '8', 'CHRISTOPHE', 'NAJARRO', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -1
# ['0824080', '6012', '8', 'CHRISTOPHE', 'NAJARRO', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# -1
# ['0824080', '6012', '8', 'CHRISTOPHE', 'NAJARRO', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# -1
# ['0825397', '6012', '8', 'MARIA', 'LORENZO', 'A', ' ', 'M/J Career Research and Decision Making']
# First nine weeks:  A
# 0824080 has -1 points
# Second nine weeks A
# 0
# ['0825397', '6012', '8', 'MARIA', 'LORENZO', 'B', 'B', 'French 1']
# First nine weeks:  B
# 0
# ['0825397', '6012', '8', 'MARIA', 'LORENZO', 'B', 'B', 'M/J Language Arts 3, Advanced']
# First nine weeks:  B
# 0
# ['0825397', '6012', '8', 'MARIA', 'LORENZO', 'B', 'B', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  B
# 0
# ['0825397', '6012', '8', 'MARIA', 'LORENZO', 'B', 'B', 'M/J Dance 1']
# First nine weeks:  B
# 0
# ['0825397', '6012', '8', 'MARIA', 'LORENZO', ' ', 'A', 'M/J Critical Thinking, ProblemSolving, and Learning Strategies']
# First nine weeks:
# 0
# ['0825397', '6012', '8', 'MARIA', 'LORENZO', 'A', 'A', 'M/J Comprehensive Science 3']
# First nine weeks:  A
# 0
# ['0825397', '6012', '8', 'MARIA', 'LORENZO', 'B', 'B', 'M/J World History, Advanced']
# First nine weeks:  B
# 0
# ['0825397', '6012', '8', 'MARIA', 'LORENZO', 'B', 'B', 'Algebra 1 Honors']
# First nine weeks:  B
# 0
# ['0832583', '6012', '6', 'ANA', 'MIDENCE', 'F', 'C', 'M/J Comprehensive Science 1']
# First nine weeks:  F
# 0825397 has 0 points
# 2
# ['0832583', '6012', '6', 'ANA', 'MIDENCE', 'F', 'D', 'M/J Language Arts 1 Through ESOL']
# First nine weeks:  F
# 3
# ['0832583', '6012', '6', 'ANA', 'MIDENCE', 'D', 'D', 'M/J United States History']
# First nine weeks:  D
# 3
# ['0832583', '6012', '6', 'ANA', 'MIDENCE', 'F', 'D', 'M/J Intensive Mathematics (Grade 6)']
# First nine weeks:  F
# 4
# ['0832583', '6012', '6', 'ANA', 'MIDENCE', 'A', ' ', 'M/J Fitness - Grade 6']
# First nine weeks:  A
# Second nine weeks A
# 4
# ['0832583', '6012', '6', 'ANA', 'MIDENCE', ' ', 'B', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:
# 4
# ['0832583', '6012', '6', 'ANA', 'MIDENCE', 'F', 'F', 'M/J Grade 6 Mathematics']
# First nine weeks:  F
# 4
# ['0832583', '6012', '6', 'ANA', 'MIDENCE', 'A', 'A', 'Spanish for Spanish Speakers 1']
# First nine weeks:  A
# 4
# ['0832583', '6012', '6', 'ANA', 'MIDENCE', 'C', 'C', 'M/J Developmental Language ArtsThrough ESOL (MC) Level 1 Reading']
# First nine weeks:  C
# 4
# ['0832584', '6012', '8', 'JOSUE', 'MIDENCE', 'B', 'B', 'Spanish for Spanish Speakers 1']
# First nine weeks:  B
# 0832583 has 4 points
# 0
# ['0832584', '6012', '8', 'JOSUE', 'MIDENCE', 'F', 'C', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  F
# 2
# ['0832584', '6012', '8', 'JOSUE', 'MIDENCE', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 2
# ['0832584', '6012', '8', 'JOSUE', 'MIDENCE', 'C', 'B', 'M/J Developmental Language ArtsThrough ESOL (MC) Level 1 Reading']
# First nine weeks:  C
# 3
# ['0832584', '6012', '8', 'JOSUE', 'MIDENCE', 'C', 'C', 'M/J Comprehensive Science 3']
# First nine weeks:  C
# 3
# ['0832584', '6012', '8', 'JOSUE', 'MIDENCE', 'D', 'F', 'M/J Language Arts 3 Through ESOL']
# First nine weeks:  D
# 2
# ['0832584', '6012', '8', 'JOSUE', 'MIDENCE', 'F', 'F', 'M/J Intensive Mathematics (Grade 8)']
# First nine weeks:  F
# 2
# ['0832584', '6012', '8', 'JOSUE', 'MIDENCE', 'C', 'F', 'M/J World History']
# First nine weeks:  C
# 0
# ['0832584', '6012', '8', 'JOSUE', 'MIDENCE', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# 0
# ['0834036', '6012', '8', 'DIANGO', 'PARRA', 'B', 'B', 'Spanish for Spanish Speakers 1']
# First nine weeks:  B
# 0832584 has 0 points
# 0
# ['0834036', '6012', '8', 'DIANGO', 'PARRA', 'F', 'D', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  F
# 1
# ['0834036', '6012', '8', 'DIANGO', 'PARRA', 'B', 'C', 'M/J Developmental Language ArtsThrough ESOL (MC) Level 1 Reading']
# First nine weeks:  B
# 0
# ['0834036', '6012', '8', 'DIANGO', 'PARRA', 'F', 'F', 'M/J Intensive Mathematics (Grade 8)']
# First nine weeks:  F
# 0
# ['0834036', '6012', '8', 'DIANGO', 'PARRA', 'D', 'F', 'M/J Language Arts 3 Through ESOL']
# First nine weeks:  D
# -1
# ['0834036', '6012', '8', 'DIANGO', 'PARRA', 'D', 'D', 'M/J Comprehensive Science 3']
# First nine weeks:  D
# -1
# ['0834036', '6012', '8', 'DIANGO', 'PARRA', 'C', 'F', 'M/J World History']
# First nine weeks:  C
# -3
# ['0834036', '6012', '8', 'DIANGO', 'PARRA', 'A', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  A
# Second nine weeks A
# -3
# ['0834036', '6012', '8', 'DIANGO', 'PARRA', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# -3
# ['0837264', '6012', '6', 'VINCENT', 'VILLAPOL', 'C', 'B', 'M/J Comprehensive Science 1']
# First nine weeks:  C
# 0834036 has -3 points
# 1
# ['0837264', '6012', '6', 'VINCENT', 'VILLAPOL', 'A', 'C', 'M/J Language Arts 1']
# First nine weeks:  A
# -1
# ['0837264', '6012', '6', 'VINCENT', 'VILLAPOL', 'B', 'C', 'M/J United States History']
# First nine weeks:  B
# -2
# ['0837264', '6012', '6', 'VINCENT', 'VILLAPOL', 'C', 'B', 'M/J Intensive Mathematics (Grade 6)']
# First nine weeks:  C
# -1
# ['0837264', '6012', '6', 'VINCENT', 'VILLAPOL', ' ', 'C', 'Business Keyboarding and Career Planning']
# First nine weeks:
# -1
# ['0837264', '6012', '6', 'VINCENT', 'VILLAPOL', 'A', 'B', 'M/J Grade 6 Mathematics']
# First nine weeks:  A
# -2
# ['0837264', '6012', '6', 'VINCENT', 'VILLAPOL', ' ', 'A', 'M/J Comprehensive Physical Education Grade 6/7']
# First nine weeks:
# -2
# ['0837264', '6012', '6', 'VINCENT', 'VILLAPOL', 'A', 'C', 'M/J Intensive Reading Enrichment(MC) Grade 6']
# First nine weeks:  A
# -4
# ['0837264', '6012', '6', 'VINCENT', 'VILLAPOL', 'A', ' ', 'M/J Fitness - Grade 6']
# First nine weeks:  A
# Second nine weeks A
# -4
# ['0837264', '6012', '6', 'VINCENT', 'VILLAPOL', 'B', ' ', 'Business Keyboarding']
# First nine weeks:  B
# Second nine weeks B
# -4
# ['0837265', '6012', '8', 'ELISA', 'ECHEMENDIA', 'B', 'F', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:  B
# 0837264 has -4 points
# -3
# ['0837265', '6012', '8', 'ELISA', 'ECHEMENDIA', 'B', ' ', 'M/J Comprehensive Physical Education Grade 7/8']
# First nine weeks:  B
# Second nine weeks B
# -3
# ['0837265', '6012', '8', 'ELISA', 'ECHEMENDIA', 'N', 'C', 'M/J Developmental Language ArtsThrough ESOL (MC) Level 1 Reading']
# First nine weeks:  N
# 8
# ['0837265', '6012', '8', 'ELISA', 'ECHEMENDIA', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 8
# ['0837265', '6012', '8', 'ELISA', 'ECHEMENDIA', 'I', 'D', 'M/J World History']
# First nine weeks:  I
# 13
# ['0837265', '6012', '8', 'ELISA', 'ECHEMENDIA', 'I', 'C', 'M/J Comprehensive Science 3']
# First nine weeks:  I
# 19
# ['0837265', '6012', '8', 'ELISA', 'ECHEMENDIA', ' ', 'D', 'M/J Language Arts 3 Through ESOL']
# First nine weeks:
# 19
# ['0837265', '6012', '8', 'ELISA', 'ECHEMENDIA', ' ', 'A', 'Spanish for Spanish Speakers 1']
# First nine weeks:
# 19
# ['0837265', '6012', '8', 'ELISA', 'ECHEMENDIA', 'B', 'B', 'M/J Two-Dimensional Studio Art 1']
# First nine weeks:  B
# 19
# ['0838951', '6012', '8', 'MARIANA', 'HURTADO', ' ', 'A', 'M/J Comprehensive Science 3']
# First nine weeks:
# 0837265 has 19 points
# 0
# ['0838951', '6012', '8', 'MARIANA', 'HURTADO', ' ', 'F', 'M/J Research 1']
# First nine weeks:
# 0
# ['0838951', '6012', '8', 'MARIANA', 'HURTADO', ' ', 'C', 'M/J Grade 8 Pre-Algebra']
# First nine weeks:
# 0
# ['0838951', '6012', '8', 'MARIANA', 'HURTADO', ' ', 'C', 'M/J Two-Dimensional Studio Art 1']
# First nine weeks:
# 0
# ['0838951', '6012', '8', 'MARIANA', 'HURTADO', ' ', 'A', 'M/J Individual/Dual Sports - Grade8']
# First nine weeks:
# 0
# ['0838951', '6012', '8', 'MARIANA', 'HURTADO', ' ', 'F', 'M/J World History']
# First nine weeks:
# 0
# ['0838951', '6012', '8', 'MARIANA', 'HURTADO', ' ', 'D', 'M/J Language Arts 3']
# First nine weeks:
# 0
# ['0838951', '6012', '8', 'MARIANA', 'HURTADO', ' ', 'B', 'M/J Spanish for Spanish Speakers,Advanced']
# First nine weeks:
# 0
